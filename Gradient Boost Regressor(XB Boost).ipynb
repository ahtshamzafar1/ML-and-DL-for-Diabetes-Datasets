# %% [markdown]
# # Table of Contents
#
# * [Introduction](#Introduction)
# * [Section 1 Functions-For-Processing](#Functions-For-Processing)
#     * [Section 1.1 Import Libraries](#Import-Libraries)
#     * [Section 1.2 Transform-a-time-series-dataset-into-a-supervised-learning-dataset](#Transform-a-time-series-dataset-into-a-supervised-learning-dataset)
#     * [Section 1.3 Split-a-univariate-dataset-into-train/test-sets](#Split-a-univariate-dataset-into-train/test-sets)
#     * [Section 1.4 Fit-a-gradient-boost-model-and-make-a-one-step-prediction](#Fit-an-random-forest-model-and-make-a-one-step-prediction)
#     * [Section 1.5 Walk-forward-validation-for-univariate-data](#Walk-forward-validation-for-univariate-data)
# * [Section 2 Processing-and-Evaluation](#Processing-and-Evaluation)
#      * [Section 2.1 Analysis-based-on-60-days-input-data](#Analysis-based-on-60-days-training-data)
#          * [Section 2.1.1 load-the-dataset](#Load-the-60-days-data)
#          * [Section 2.1.2 Evaluate](#Analysis-based-on-60-days-training-data)
#          * [Section 2.1.3 Insight](#Insight-for-60-days-Training-Data-Evaluation)
#      * [Section 2.2 Analysis-based-on-30-days-input-data](#Analysis-Based-On-30-Days-Training-Data)
#          * [Section 2.2.1 Load-the-data](#Load-the-30-days-data)
#          * [Section 2.2.2 Evaluate](#Analysis-based-on-30-days-training-data)
#          * [Section 2.2.3 Insight](#Insight-for-30-days-Training-Data)
# * [Section 3 Summary](#Summary)
#      * [Section 3.1 Suggestions](#Suggestions)

# %% [markdown]
# # Introduction <a class="anchor" id="Introduction"></a>
#
# This notebook contains data analysis and processing of glucose data of a patient to obtain key insights and get future predictions of data.
#
# The notebook is divided into two sections:
# 1. In the first section all the fuctions have been defined that can be called anywhere is the notebook. These functions include:
#
#  a) Transform a time series dataset into a supervised learning dataset.
#
#  b) Split a univariate dataset into train/test sets
#
#  c) Fit a gradient boost regressor and make a one step prediction
#
#  d) Walk-forward validation for univariate data
#
#
# 2. The section 2 utilizes all the fuctions that have been developed in section 1 to evaluate and predict the results.
#
# ## a) Transform a time series dataset into a supervised learning dataset
# This step transforms time series data into a supervised learning dataset for better prediction scores. The dataset is made in such a way that the original univariate data is provided multiple columns which, these colums have values from previous datapoints. Ths creates a dependency and colinear relation between datapoints as they progress. When this relation between datapoints is learned by the model, it performs better as compared to a non-supervised dataset.
#
# ## b) Split a univariate dataset into train/test sets
# This step is key for any model, we need to divide our dataset into train and test sets. Generally a 80% train and 20% test is considered.

# %% [markdown]
# ##  c) Fit a gradient boost regressor and make a one step prediction
# Gradient boosting is one of the most popular machine learning algorithms for tabular datasets. It is powerful enough to find any nonlinear relationship between your model target and features and has great usability that can deal with missing values, outliers, and high cardinality categorical values on your features without any special treatment. While you can build barebone gradient boosting trees using some popular libraries such as XGBoost or LightGBM without knowing any details of the algorithm, you still want to know how it works when you start tuning hyper-parameters, customizing the loss functions, etc., to get better quality on your model.
#
# ![1_KmFFQVKyDPAD5Qu66hHbxg.png](attachment:1_KmFFQVKyDPAD5Qu66hHbxg.png)
#
# 1. The first step is making a very naive prediction on the target y. We make the initial prediction F₀ as an overall average of y:
#
# 2. To improve our prediction, we will focus on the residuals (i.e. prediction errors) from the first step because that is what we want to minimize to get a better prediction.
# 3. To minimize these residuals, we are building a regression tree model with x as its feature and the residuals r₁ = y − mean(y) as its target. The reasoning behind that is if we can find some patterns between x and r₁ by building the additional weak model, we can reduce the residuals by utilizing it.
#
# ## d) Walk-forward validation for univariate data
# Walk forward validation is an important step in this kind of data, specially if the data is continuously streaming in. We need a model that can cater for new data points while predicting the next data points. In this notebook, we perform a 12 point walk forward validation.
#
# In short we train our model on a specific amount of training data and predict the next 12 data points, after ths prediction the 12 predicted data points are then merged into the training data and next 12 data points are predicted. In this way we can take input from real time streaming data and add it to the process of predicting future values.

# %% [markdown]
# # Functions-For-Processing

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
from numpy import asarray
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn import datasets, ensemble
from matplotlib import pyplot

# %% [markdown]
# ## Transform a time series dataset into a supervised learning dataset
#
# This steps includes converting a naive time series data into a supervised dataset. The number of values to be used as lag for supervised dataset is sent as a parameter to the function.
#
#
# The function takes the original dataset and add columns infront of each data value. These columns are bascially the preceding values to that particular value, in the time series.

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols = list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
    # put it all together
    agg = concat(cols, axis=1)
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# %% [markdown]
# ## Split a univariate dataset into train/test sets

# %%
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]

# %% [markdown]
# ## Fit a gradient boost model and make a one step prediction

# %%
def gradient_boost_forecast(train, testX):
    # transform list into array
    train = asarray(train)
    # split into input and output columns
    trainX, trainy = train[:, :-1], train[:, -1]
    # fit model
    model = ensemble.GradientBoostingRegressor()
    model.fit(trainX, trainy)
    # make a one-step prediction
    yhat = model.predict([testX])
    return yhat[0]

# %% [markdown]
# ## Walk-forward validation for univariate data

# %%
def walk_forward_validation(data, n_test):
    data = series_to_supervised(data, n_in=6)
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # step over each time-step in the test set
    for i in range(len(test)):
        # split test row into input and output columns
        testX, testy = test[i, :-1], test[i, -1]
        # fit model on history and make a prediction
        yhat = gradient_boost_forecast(history, testX)
        # store forecast in list of predictions
        predictions.append(yhat)
        # history.append(test[i]) # use only if: add actual observation to history for the next loop
        # summarize progress
        print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
    # estimate prediction error
    error = mean_absolute_error(test[:, -1], predictions)
    rmse = mean_squared_error(test[:, -1], predictions)
    rmse = (rmse) ** (0.5)
    return error, test[:, -1], predictions, rmse

# %% [markdown]
# # Processing-and-Evaluation

# %% [markdown]
# ## Analysis based on 60 days training data

# %% [markdown]
# ### Load the 60 days data

# %%
series = read_csv(
    r'C:\Users\ahtis\OneDrive\Desktop\ARIMA\data\data.csv', header=0, index_col=0)
values = series.values

# Read 60 days of data from the dataset for validation. Each datapoint is recorded with 5 minute interval in between.
# (12 points in an hour, 288 points in a day, 17280 in 60 days)

data = values[0:17280]
data1 = values[0:17280]
pyplot.plot(data, label='Glucose Data')

pyplot.xlabel('Data Index')
pyplot.ylabel('Glucose Level (mg/dL)')

data1 = pd.DataFrame(data)
data1.describe()
# Out:
#                   0
# count  17274.000000
# mean     129.411485
# std       41.198385
# min       39.000000
# 25%      102.000000
# 50%      122.000000
# 75%      150.000000
# max      386.000000

# %% [markdown]
# ### Analysis based on 60 days training data

# %%
mean_abs_error = list()
for i in range(3):
    mae, y, yhat,rmse = walk_forward_validation(data, 72)
    print('MAE: %.3f' % mae)
    print('RMSE: %.3f' % rmse)
    #data = values[len(data)-2:len(data)+len(data)-2, :]
    #yhat = np.asarray(yhat)
    # print('yhat',yhat.shape)
    #yhat_append = series_to_supervised(yhat, n_in=6)
    #print('yhat append',yhat_append.shape)
    #y_append = np.asarray(y)
    #data = np.append(data, y_append)
    #data = np.reshape(data, (-1, 1))
    data = values[0:len(data)+72,:]
    mean_abs_error.append(mae)
    pyplot.plot(y, label='Expected')
    pyplot.plot(yhat, label='Predicted')
    #pyplot.title('Loss: MAE = %f' % (mae) , 'Loss: MSE = %f' % (mse) )
    pyplot.legend()
    pyplot.show()
# Out:
# >expected=84.0, predicted=81.2
# >expected=85.0, predicted=84.5
# >expected=86.0, predicted=85.7
# >expected=86.0, predicted=87.6
# >expected=82.0, predicted=88.0
# >expected=82.0, predicted=82.5
# >expected=88.0, predicted=82.3
# >expected=91.0, predicted=89.8
# >expected=96.0, predicted=92.7
# >expected=96.0, predicted=97.1
# >expected=102.0, predicted=97.4
# >expected=105.0, predicted=103.6
# >expected=111.0, predicted=106.9
# >expected=113.0, predicted=113.5
# >expected=111.0, predicted=115.8
# >expected=110.0, predicted=112.6
# >expected=111.0, predicted=109.9
# >expected=110.0, predicted=111.0
# >expected=114.0, predicted=109.3
# >expected=116.0, predicted=114.1
# >expected=112.0, predicted=116.2
# >expected=110.0, predicted=111.6
# >expected=104.0, predicted=109.4
# >expected=102.0, predicted=103.3
# >expected=101.0, predicted=100.4
# >expected=99.0, predicted=100.8
# >expected=99.0, predicted=98.3
# >expected=99.0, predicted=98.9
# >expected=99.0, predicted=99.5
# >expected=99.0, predicted=99.7
# >expected=102.0, predicted=99.7
# >expected=108.0, predicted=102.6
# >expected=111.0, predicted=109.5
# >expected=112.0, predicted=112.5
# >expected=113.0, predicted=113.6
# >expected=115.0, predicted=114.8
# >expected=116.0, predicted=116.5
# >expected=117.0, predicted=116.6
# >expected=118.0, predicted=116.5
# >expected=119.0, predicted=118.0
# >expected=120.0, predicted=119.2
# >expected=121.0, predicted=120.1
# >expected=117.0, predicted=121.7
# >expected=117.0, predicted=116.0
# >expected=119.0, predicted=116.0
# >expected=120.0, predicted=119.0
# >expected=120.0, predicted=119.9
# >expected=121.0, predicted=119.9
# >expected=118.0, predicted=121.7
# >expected=118.0, predicted=117.9
# >expected=119.0, predicted=117.9
# >expected=120.0, predicted=119.0
# >expected=116.0, predicted=119.9
# >expected=118.0, predicted=115.4
# >expected=119.0, predicted=117.9
# >expected=117.0, predicted=119.0
# >expected=118.0, predicted=116.0
# >expected=115.0, predicted=118.0
# >expected=115.0, predicted=115.0
# >expected=117.0, predicted=114.7
# >expected=126.0, predicted=116.2
# >expected=127.0, predicted=127.5
# >expected=133.0, predicted=128.8
# >expected=136.0, predicted=135.8
# >expected=139.0, predicted=138.3
# >expected=150.0, predicted=140.2
# >expected=156.0, predicted=152.2
# >expected=162.0, predicted=158.9
# >expected=165.0, predicted=164.9
# >expected=167.0, predicted=167.4
# >expected=171.0, predicted=169.1
# >expected=173.0, predicted=171.9
# MAE: 2.102
# RMSE: 2.942
# >expected=174.0, predicted=174.2
# >expected=172.0, predicted=173.5
# >expected=169.0, predicted=170.9
# >expected=166.0, predicted=166.9
# >expected=168.0, predicted=165.0
# >expected=169.0, predicted=166.5
# >expected=165.0, predicted=166.9
# >expected=165.0, predicted=163.3
# >expected=163.0, predicted=163.3
# >expected=162.0, predicted=162.2
# >expected=163.0, predicted=159.8
# >expected=161.0, predicted=162.0
# >expected=161.0, predicted=159.9
# >expected=158.0, predicted=160.4
# >expected=150.0, predicted=156.2
# >expected=149.0, predicted=145.6
# >expected=149.0, predicted=144.9
# >expected=148.0, predicted=145.0
# >expected=147.0, predicted=146.3
# >expected=147.0, predicted=145.7
# >expected=147.0, predicted=145.9
# >expected=148.0, predicted=145.9
# >expected=155.0, predicted=147.3
# >expected=152.0, predicted=154.0
# >expected=156.0, predicted=152.5
# >expected=155.0, predicted=155.7
# >expected=151.0, predicted=154.0
# >expected=148.0, predicted=150.4
# >expected=145.0, predicted=147.0
# >expected=147.0, predicted=142.8
# >expected=149.0, predicted=145.4
# >expected=145.0, predicted=147.2
# >expected=141.0, predicted=143.2
# >expected=134.0, predicted=139.3
# >expected=135.0, predicted=132.0
# >expected=137.0, predicted=132.5
# >expected=136.0, predicted=136.4
# >expected=135.0, predicted=135.7
# >expected=134.0, predicted=134.5
# >expected=134.0, predicted=133.7
# >expected=137.0, predicted=133.3
# >expected=133.0, predicted=137.3
# >expected=128.0, predicted=132.2
# >expected=129.0, predicted=126.8
# >expected=131.0, predicted=128.7
# >expected=133.0, predicted=130.1
# >expected=128.0, predicted=133.1
# >expected=126.0, predicted=127.6
# >expected=124.0, predicted=126.1
# >expected=126.0, predicted=123.4
# >expected=128.0, predicted=125.8
# >expected=126.0, predicted=127.6
# >expected=127.0, predicted=126.2
# >expected=125.0, predicted=127.0
# >expected=124.0, predicted=125.2
# >expected=123.0, predicted=124.0
# >expected=124.0, predicted=122.3
# >expected=120.0, predicted=124.0
# >expected=117.0, predicted=119.2
# >expected=112.0, predicted=115.8
# >expected=110.0, predicted=110.6
# >expected=105.0, predicted=108.3
# >expected=101.0, predicted=103.3
# >expected=95.0, predicted=99.4
# >expected=93.0, predicted=94.2
# >expected=92.0, predicted=91.2
# >expected=92.0, predicted=91.1
# >expected=97.0, predicted=92.4
# >expected=102.0, predicted=97.6
# >expected=102.0, predicted=102.9
# >expected=102.0, predicted=103.2
# >expected=100.0, predicted=103.2
# MAE: 2.379
# RMSE: 2.830
# >expected=98.0, predicted=100.7
# >expected=99.0, predicted=98.4
# >expected=98.0, predicted=99.3
# >expected=99.0, predicted=98.0
# >expected=99.0, predicted=99.3
# >expected=99.0, predicted=99.6
# >expected=101.0, predicted=99.7
# >expected=105.0, predicted=102.1
# >expected=106.0, predicted=106.6
# >expected=109.0, predicted=108.0
# >expected=111.0, predicted=111.2
# >expected=109.0, predicted=112.6
# >expected=109.0, predicted=110.1
# >expected=110.0, predicted=109.9
# >expected=113.0, predicted=109.7
# >expected=113.0, predicted=113.6
# >expected=110.0, predicted=113.4
# >expected=110.0, predicted=109.6
# >expected=107.0, predicted=109.6
# >expected=105.0, predicted=106.1
# >expected=104.0, predicted=104.5
# >expected=89.0, predicted=103.8
# >expected=84.0, predicted=86.9
# >expected=81.0, predicted=82.7
# >expected=85.0, predicted=79.9
# >expected=89.0, predicted=84.8
# >expected=93.0, predicted=89.5
# >expected=97.0, predicted=93.5
# >expected=101.0, predicted=99.2
# >expected=106.0, predicted=104.1
# >expected=109.0, predicted=108.5
# >expected=114.0, predicted=111.8
# >expected=115.0, predicted=116.6
# >expected=116.0, predicted=118.3
# >expected=115.0, predicted=116.9
# >expected=117.0, predicted=116.3
# >expected=116.0, predicted=116.7
# >expected=112.0, predicted=116.1
# >expected=111.0, predicted=111.6
# >expected=109.0, predicted=110.8
# >expected=108.0, predicted=108.7
# >expected=107.0, predicted=107.5
# >expected=105.0, predicted=106.3
# >expected=104.0, predicted=104.6
# >expected=104.0, predicted=103.8
# >expected=105.0, predicted=104.1
# >expected=104.0, predicted=105.3
# >expected=104.0, predicted=104.5
# >expected=104.0, predicted=104.5
# >expected=106.0, predicted=104.5
# >expected=113.0, predicted=106.9
# >expected=116.0, predicted=114.0
# >expected=120.0, predicted=116.9
# >expected=121.0, predicted=121.6
# >expected=121.0, predicted=123.2
# >expected=122.0, predicted=122.8
# >expected=122.0, predicted=123.0
# >expected=122.0, predicted=122.6
# >expected=119.0, predicted=122.6
# >expected=114.0, predicted=118.9
# >expected=111.0, predicted=112.7
# >expected=106.0, predicted=109.6
# >expected=103.0, predicted=104.6
# >expected=101.0, predicted=101.4
# >expected=98.0, predicted=100.2
# >expected=96.0, predicted=97.0
# >expected=94.0, predicted=95.2
# >expected=87.0, predicted=94.4
# >expected=85.0, predicted=85.3
# >expected=84.0, predicted=84.3
# >expected=85.0, predicted=84.2
# >expected=90.0, predicted=85.5
# MAE: 1.982
# RMSE: 2.924

# %% [markdown]
# ### Insight for 60 days Training Data Evaluation

# %% [markdown]
# Using the 60 Day time period for our data, we are able to iterate two time over the data set. Here we are predicting next 72 points which is next 6 hours of data.
#
# The Key Insight is that as we progress in the foward 72 step validation the MAE and MSE remains almost constant.
#
# In first prediction the MAE is at 2.102 and RMSE is at 2.942.
#
# In second iteration the MAE is at 2.379 and RMSE is at 2.830.
#
# In Third iteration the MAE is at 1.982 and RMSE is at 2.924.
#
# Model is considered to be useful if MAE and RMSE is less than 5 in general, since the trend is maintained and loss parameters are in desired range the model can be considered for further testing. Higher MAE/RMSE can further distort the prediction as compared to original values.

# %% [markdown]
# ## Analysis Based On 30 Days Training Data

# %% [markdown]
# ### Load the 30 days data

# %%
series = read_csv(
    r'C:\Users\ahtis\OneDrive\Desktop\ARIMA\data\data.csv', header=0, index_col=0)
values = series.values

# Read 60 days of data from the dataset for validation. Each datapoint is recorded with 5 minute interval in between.
# (12 points in an hour, 288 points in a day, 8640 in 30 days)

data = values[0:8640]
data1 = values[0:8640]
pyplot.plot(data, label='Glucose Data')

pyplot.xlabel('Data Index')
pyplot.ylabel('Glucose Level (mg/dL)')

data1 = pd.DataFrame(data)
data1.describe()
# Out:
#                  0
# count  8634.000000
# mean    131.939889
# std      44.110320
# min      39.000000
# 25%     102.000000
# 50%     125.000000
# 75%     154.000000
# max     386.000000

# %% [markdown]
# ### Analysis based on 30 days training data

# %%
mean_abs_error = list()
for i in range(3):
    mae, y, yhat, rmse = walk_forward_validation(data, 72)
    print('MAE: %.3f' % mae)
    print('RMSE: %.3f' % rmse)
    #data = values[len(data)-2:len(data)+len(data)-2, :]
    #yhat = np.asarray(yhat)
    # print('yhat',yhat.shape)
    #yhat_append = series_to_supervised(yhat, n_in=6)
    #print('yhat append',yhat_append.shape)
    #y_append = np.asarray(y)
    #data = np.append(data, y_append)
    #data = np.reshape(data, (-1, 1))
    data = values[0:len(data)+72,:]
    mean_abs_error.append(mae)
    pyplot.plot(y, label='Expected')
    pyplot.plot(yhat, label='Predicted')
   # pyplot.title('Loss: MAE = %f' % (mae) ,'Loss: MSE = %f' % (mse))
    pyplot.legend()
    pyplot.show()
# Out:
# >expected=110.0, predicted=110.8
# >expected=110.0, predicted=110.5
# >expected=113.0, predicted=110.3
# >expected=116.0, predicted=114.0
# >expected=116.0, predicted=116.5
# >expected=116.0, predicted=116.3
# >expected=120.0, predicted=115.9
# >expected=121.0, predicted=121.3
# >expected=122.0, predicted=122.6
# >expected=124.0, predicted=122.1
# >expected=126.0, predicted=125.3
# >expected=127.0, predicted=126.8
# >expected=127.0, predicted=127.5
# >expected=126.0, predicted=126.7
# >expected=127.0, predicted=125.9
# >expected=127.0, predicted=126.7
# >expected=127.0, predicted=126.7
# >expected=127.0, predicted=126.6
# >expected=128.0, predicted=126.6
# >expected=128.0, predicted=128.2
# >expected=128.0, predicted=128.1
# >expected=128.0, predicted=128.1
# >expected=128.0, predicted=128.1
# >expected=128.0, predicted=128.1
# >expected=130.0, predicted=128.1
# >expected=131.0, predicted=130.6
# >expected=134.0, predicted=130.6
# >expected=135.0, predicted=134.0
# >expected=136.0, predicted=134.8
# >expected=138.0, predicted=137.0
# >expected=143.0, predicted=138.2
# >expected=146.0, predicted=144.2
# >expected=153.0, predicted=145.6
# >expected=158.0, predicted=154.6
# >expected=160.0, predicted=160.5
# >expected=160.0, predicted=162.3
# >expected=162.0, predicted=161.1
# >expected=162.0, predicted=161.6
# >expected=165.0, predicted=161.3
# >expected=167.0, predicted=164.6
# >expected=167.0, predicted=167.0
# >expected=168.0, predicted=167.0
# >expected=163.0, predicted=169.1
# >expected=158.0, predicted=162.2
# >expected=158.0, predicted=156.2
# >expected=158.0, predicted=155.8
# >expected=158.0, predicted=156.2
# >expected=158.0, predicted=156.2
# >expected=158.0, predicted=156.9
# >expected=160.0, predicted=156.9
# >expected=162.0, predicted=160.0
# >expected=163.0, predicted=161.2
# >expected=162.0, predicted=163.2
# >expected=163.0, predicted=161.2
# >expected=158.0, predicted=162.8
# >expected=155.0, predicted=156.6
# >expected=155.0, predicted=152.2
# >expected=153.0, predicted=152.5
# >expected=152.0, predicted=151.2
# >expected=152.0, predicted=152.0
# >expected=148.0, predicted=152.0
# >expected=145.0, predicted=147.0
# >expected=143.0, predicted=144.0
# >expected=139.0, predicted=143.2
# >expected=129.0, predicted=137.2
# >expected=116.0, predicted=127.2
# >expected=108.0, predicted=111.5
# >expected=102.0, predicted=104.1
# >expected=98.0, predicted=97.1
# >expected=98.0, predicted=94.8
# >expected=101.0, predicted=96.1
# >expected=106.0, predicted=100.6
# MAE: 2.048
# RMSE: 2.925
# >expected=111.0, predicted=107.1
# >expected=115.0, predicted=111.8
# >expected=119.0, predicted=117.9
# >expected=125.0, predicted=121.2
# >expected=131.0, predicted=127.1
# >expected=138.0, predicted=133.5
# >expected=142.0, predicted=141.1
# >expected=150.0, predicted=143.9
# >expected=156.0, predicted=152.7
# >expected=164.0, predicted=159.2
# >expected=172.0, predicted=168.7
# >expected=180.0, predicted=173.9
# >expected=187.0, predicted=182.7
# >expected=193.0, predicted=189.6
# >expected=196.0, predicted=192.8
# >expected=191.0, predicted=197.3
# >expected=185.0, predicted=190.9
# >expected=180.0, predicted=184.6
# >expected=167.0, predicted=178.7
# >expected=150.0, predicted=161.1
# >expected=132.0, predicted=138.0
# >expected=112.0, predicted=121.7
# >expected=100.0, predicted=101.1
# >expected=90.0, predicted=92.4
# >expected=82.0, predicted=83.1
# >expected=81.0, predicted=77.6
# >expected=84.0, predicted=78.5
# >expected=88.0, predicted=81.8
# >expected=93.0, predicted=88.8
# >expected=96.0, predicted=94.0
# >expected=101.0, predicted=96.9
# >expected=103.0, predicted=103.8
# >expected=107.0, predicted=105.1
# >expected=113.0, predicted=108.7
# >expected=119.0, predicted=115.5
# >expected=125.0, predicted=121.5
# >expected=130.0, predicted=127.1
# >expected=133.0, predicted=133.2
# >expected=137.0, predicted=136.1
# >expected=139.0, predicted=140.6
# >expected=142.0, predicted=140.1
# >expected=143.0, predicted=142.8
# >expected=145.0, predicted=144.1
# >expected=143.0, predicted=145.0
# >expected=142.0, predicted=143.8
# >expected=138.0, predicted=141.1
# >expected=134.0, predicted=137.6
# >expected=126.0, predicted=132.7
# >expected=118.0, predicted=122.8
# >expected=107.0, predicted=116.0
# >expected=96.0, predicted=103.3
# >expected=92.0, predicted=91.2
# >expected=90.0, predicted=88.4
# >expected=92.0, predicted=87.1
# >expected=90.0, predicted=90.3
# >expected=85.0, predicted=89.1
# >expected=85.0, predicted=85.2
# >expected=84.0, predicted=85.6
# >expected=83.0, predicted=83.4
# >expected=81.0, predicted=83.0
# >expected=84.0, predicted=82.7
# >expected=84.0, predicted=84.3
# >expected=86.0, predicted=84.3
# >expected=87.0, predicted=87.0
# >expected=89.0, predicted=87.0
# >expected=92.0, predicted=89.9
# >expected=94.0, predicted=92.3
# >expected=96.0, predicted=94.1
# >expected=99.0, predicted=96.9
# >expected=101.0, predicted=99.8
# >expected=103.0, predicted=102.6
# >expected=104.0, predicted=104.7
# MAE: 3.243
# RMSE: 4.123
# >expected=106.0, predicted=105.6
# >expected=108.0, predicted=108.3
# >expected=106.0, predicted=109.0
# >expected=105.0, predicted=107.3
# >expected=103.0, predicted=106.3
# >expected=101.0, predicted=103.6
# >expected=100.0, predicted=101.3
# >expected=99.0, predicted=100.0
# >expected=99.0, predicted=99.0
# >expected=99.0, predicted=99.0
# >expected=99.0, predicted=99.4
# >expected=100.0, predicted=99.5
# >expected=100.0, predicted=100.7
# >expected=98.0, predicted=101.1
# >expected=100.0, predicted=98.8
# >expected=105.0, predicted=101.1
# >expected=106.0, predicted=107.1
# >expected=106.0, predicted=107.7
# >expected=104.0, predicted=107.7
# >expected=104.0, predicted=104.8
# >expected=106.0, predicted=104.2
# >expected=106.0, predicted=107.3
# >expected=106.0, predicted=107.3
# >expected=107.0, predicted=107.3
# >expected=105.0, predicted=107.3
# >expected=102.0, predicted=106.3
# >expected=103.0, predicted=101.0
# >expected=103.0, predicted=103.8
# >expected=101.0, predicted=103.8
# >expected=96.0, predicted=101.2
# >expected=96.0, predicted=96.3
# >expected=97.0, predicted=96.6
# >expected=98.0, predicted=97.9
# >expected=98.0, predicted=98.6
# >expected=100.0, predicted=98.6
# >expected=104.0, predicted=101.3
# >expected=105.0, predicted=105.1
# >expected=103.0, predicted=107.3
# >expected=102.0, predicted=104.1
# >expected=103.0, predicted=102.3
# >expected=106.0, predicted=104.1
# >expected=108.0, predicted=107.3
# >expected=110.0, predicted=108.5
# >expected=115.0, predicted=110.4
# >expected=116.0, predicted=116.5
# >expected=116.0, predicted=116.8
# >expected=112.0, predicted=116.6
# >expected=112.0, predicted=112.1
# >expected=114.0, predicted=111.6
# >expected=116.0, predicted=114.6
# >expected=119.0, predicted=115.9
# >expected=123.0, predicted=120.3
# >expected=127.0, predicted=124.1
# >expected=133.0, predicted=128.0
# >expected=138.0, predicted=135.3
# >expected=140.0, predicted=140.4
# >expected=142.0, predicted=141.8
# >expected=146.0, predicted=142.9
# >expected=153.0, predicted=146.1
# >expected=154.0, predicted=154.3
# >expected=156.0, predicted=156.2
# >expected=155.0, predicted=156.8
# >expected=158.0, predicted=154.1
# >expected=166.0, predicted=157.1
# >expected=167.0, predicted=166.8
# >expected=168.0, predicted=166.8
# >expected=168.0, predicted=168.6
# >expected=162.0, predicted=168.6
# >expected=145.0, predicted=160.9
# >expected=152.0, predicted=137.6
# >expected=152.0, predicted=149.6
# >expected=160.0, predicted=150.5
# MAE: 2.461
# RMSE: 3.827

# %% [markdown]
# ### Insight for 30 days Training Data

# %% [markdown]
# Using the 30 Day time period for our data, we are able to iterate four times over the data set. Here we are predicting next 72 points which is next 6 hours of data.
#
# The Key Insight is that as we progress in the foward 72 step validation the MAE and MSE almost remains constant.
#
# In first iteration the MAE is at 2.048 and RMSE is at 2.925.
#
# In second iteration the MAE is at 3.243 and RMSE is at 4.123.
#
# In third iteration the MAE is at 2.461 and RMSE is at 3.827.
#
#
# Model is considered to be useful if MAE and RMSE is less than 5 in general, since the trend is maintained and loss parameters are in desired range the model can be considered for further testing. Higher MAE/RMSE can further distort the prediction as compared to original values.

# %% [markdown]
# # Summary

# %% [markdown]
# If we increase the number of iterations the MAE and RMSE is almost constant, with slight up and down variations based on particular input data. The model is behaving good in terms of accuracy and is able to capture future prediction trends.
#
# ## Suggestions
#
# 1. Increasing the input dataset may(not necessarily) decrease the overall error rate.
# 2. Model is performing good enough and can be deployed in a practical scenario on test trials for further evaluation.
